# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("./output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID               City      Lat       Lng  Max Temp  Humidity  \
# 0        0              marka   1.7159   44.7717     26.93        88
# 1        1          ugoofaaru   5.6667   73.0000     27.47        78
# 2        2            iqaluit  63.7506  -68.5145     -0.15        80
# 3        3              la'ie  21.6477 -157.9253     28.92        82
# 4        4  port-aux-francais -49.3500   70.2167      4.58        90
#
#    Cloudiness  Wind Speed Country        Date
# 0          97        5.35      SO  1698172787
# 1          22        3.71      MV  1698172787
# 2          75        3.60      CA  1698172788
# 3           9        0.89      US  1698172788
# 4         100       11.96      TF  1698172788

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 750,
    frame_height = 500,
    size = "Humidity",
    color = 'City'
)

# Display the map 
map_plot_1
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# Criteria: 0 < Max Temp < 5°C
narrowed_df = city_data_df[(city_data_df.loc[:, 'Max Temp'] > 0) & (city_data_df.loc[:, 'Max Temp'] < 5)]

# Drop any rows with null values
clean_df= narrowed_df.dropna(how = 'any')

# Display sample data
clean_df
# Out:
#      City_ID                      City      Lat       Lng  Max Temp  Humidity  \
# 4          4         port-aux-francais -49.3500   70.2167      4.58        90
# 5          5                  qaqortoq  60.7167  -46.0333      1.90        48
# 9          9                 grytviken -54.2811  -36.5092      1.29        93
# 12        12                isafjordur  66.0755  -23.1240      3.02        87
# 46        46                 kolyshley  52.7005   44.5367      2.00        74
# 64        64                    anadyr  64.7500  177.4833      0.28        80
# 89        89                  ulaangom  49.9811   92.0667      1.07        55
# 100      100               olonkinbyen  70.9221   -8.7187      3.54        93
# 108      108                   selfoss  63.9331  -20.9971      1.69        79
# 128      128               vilyuchinsk  52.9306  158.4028      2.18        80
# 140      140                 berezovyy  51.6667  135.7000      0.29        81
# 164      164             kamen'-na-obi  53.7884   81.3423      2.47        96
# 173      173                      nuuk  64.1835  -51.7216      0.34        80
# 211      211                      nehe  48.4833  124.8333      4.65        55
# 223      223                     sitka  57.0531 -135.3300      2.94        44
# 255      255                gadzhiyevo  69.2551   33.3362      0.64        83
# 258      258                    suntar  62.1444  117.6319      1.15        87
# 263      263             labrador city  52.9463  -66.9114      2.95        75
# 267      267                 trondheim  63.4305   10.3951      4.44        94
# 271      271                choibalsan  48.0667  114.5000      4.45        48
# 282      282                     altay  47.8667   88.1167      0.36        46
# 288      288                   mogocha  53.7333  119.7667      0.67        73
# 322      322                   terrace  54.5163 -128.6035      3.45        47
# 338      338  petropavlovsk-kamchatsky  53.0452  158.6483      1.36        81
# 367      367                   merritt  50.1123 -120.7942      0.74        83
# 436      436                   nogliki  51.8333  143.1667      4.63        85
# 439      439                      bodo  67.2800   14.4050      3.30        84
# 445      445                  whistler  50.1164 -122.9695      2.57        75
# 475      475                     lensk  60.7253  114.9278      0.27        75
# 522      522                  haapsalu  58.9431   23.5414      4.39        85
# 527      527            promyshlennaya  54.9159   85.6385      0.53        87
# 531      531                      hovd  48.0056   91.6419      2.78        29
# 562      562                 ketchikan  55.3422 -131.6461      3.99        38
# 590      590                    hailar  49.2000  119.7000      4.04        52
#
#      Cloudiness  Wind Speed Country        Date
# 4           100       11.96      TF  1698172788
# 5             1        2.75      GL  1698172788
# 9            97        6.00      GS  1698172789
# 12           75        0.00      IS  1698172789
# 46          100        4.98      RU  1698172796
# 64            0        3.00      RU  1698172799
# 89          100        1.16      MN  1698172805
# 100          73        2.48      SJ  1698172808
# 108         100        3.28      IS  1698172810
# 128          16        2.95      RU  1698172815
# 140          51        0.83      RU  1698172818
# 164         100        8.78      RU  1698172823
# 173          75        7.72      GL  1698172826
# 211           6        3.35      CN  1698172836
# 223           0        2.06      US  1698172839
# 255          99        3.63      RU  1698172845
# 258         100        4.09      RU  1698172845
# 263         100        6.17      CA  1698172846
# 267          86        2.95      NO  1698172847
# 271          38        6.85      MN  1698172848
# 282           9        2.60      CN  1698172850
# 288         100        0.86      RU  1698172851
# 322          75        6.69      CA  1698172809
# 338          20        4.92      RU  1698172859
# 367         100        1.79      CA  1698172866
# 436         100        0.89      RU  1698172880
# 439          75        8.75      NO  1698172881
# 445         100        0.00      CA  1698172854
# 475         100        4.93      RU  1698172888
# 522          18        3.42      EE  1698172898
# 527         100        8.61      RU  1698172899
# 531          72        2.87      MN  1698172900
# 562           0        3.60      US  1698172905
# 590          15        3.94      CN  1698172911

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = clean_df.copy().drop(columns = ['City_ID', 'Max Temp', 'Cloudiness', 'Wind Speed', 'Date'])

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df.insert(len(hotel_df.columns), 'Hotel Name', value = '')

# Display sample data
hotel_df
# Out:
#                          City      Lat       Lng  Humidity Country Hotel Name
# 4           port-aux-francais -49.3500   70.2167        90      TF
# 5                    qaqortoq  60.7167  -46.0333        48      GL
# 9                   grytviken -54.2811  -36.5092        93      GS
# 12                 isafjordur  66.0755  -23.1240        87      IS
# 46                  kolyshley  52.7005   44.5367        74      RU
# 64                     anadyr  64.7500  177.4833        80      RU
# 89                   ulaangom  49.9811   92.0667        55      MN
# 100               olonkinbyen  70.9221   -8.7187        93      SJ
# 108                   selfoss  63.9331  -20.9971        79      IS
# 128               vilyuchinsk  52.9306  158.4028        80      RU
# 140                 berezovyy  51.6667  135.7000        81      RU
# 164             kamen'-na-obi  53.7884   81.3423        96      RU
# 173                      nuuk  64.1835  -51.7216        80      GL
# 211                      nehe  48.4833  124.8333        55      CN
# 223                     sitka  57.0531 -135.3300        44      US
# 255                gadzhiyevo  69.2551   33.3362        83      RU
# 258                    suntar  62.1444  117.6319        87      RU
# 263             labrador city  52.9463  -66.9114        75      CA
# 267                 trondheim  63.4305   10.3951        94      NO
# 271                choibalsan  48.0667  114.5000        48      MN
# 282                     altay  47.8667   88.1167        46      CN
# 288                   mogocha  53.7333  119.7667        73      RU
# 322                   terrace  54.5163 -128.6035        47      CA
# 338  petropavlovsk-kamchatsky  53.0452  158.6483        81      RU
# 367                   merritt  50.1123 -120.7942        83      CA
# 436                   nogliki  51.8333  143.1667        85      RU
# 439                      bodo  67.2800   14.4050        84      NO
# 445                  whistler  50.1164 -122.9695        75      CA
# 475                     lensk  60.7253  114.9278        75      RU
# 522                  haapsalu  58.9431   23.5414        85      EE
# 527            promyshlennaya  54.9159   85.6385        87      RU
# 531                      hovd  48.0056   91.6419        29      MN
# 562                 ketchikan  55.3422 -131.6461        38      US
# 590                    hailar  49.2000  119.7000        52      CN

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    'limit' : 1,
    'filter' : '',
    'bias' : '',
    'categories' : 'accommodation.hotel',
    'apiKey' : geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = hotel_df.loc[index, 'Lat']
    longitude = hotel_df.loc[index, 'Lng']
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params['filter'] = f'circle:{longitude},{latitude},{radius}'
    params['bias'] = f'proximity:{longitude},{latitude}'
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"

    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# port-aux-francais - nearest hotel: Keravel
# qaqortoq - nearest hotel: Hotel Qaqortoq
# grytviken - nearest hotel: No hotel found
# isafjordur - nearest hotel: Hótel Horn
# kolyshley - nearest hotel: No hotel found
# anadyr - nearest hotel: Гостевой дом
# ulaangom - nearest hotel: АНДУУД
# olonkinbyen - nearest hotel: No hotel found
# selfoss - nearest hotel: Miðgarður
# vilyuchinsk - nearest hotel: Победа
# berezovyy - nearest hotel: No hotel found
# kamen'-na-obi - nearest hotel: Гостиница "Обь"
# nuuk - nearest hotel: Nordbo
# nehe - nearest hotel: No hotel found
# sitka - nearest hotel: Aspen Suites Hotel
# gadzhiyevo - nearest hotel: Оазис
# suntar - nearest hotel: No hotel found
# labrador city - nearest hotel: Carol Inn
# trondheim - nearest hotel: Thon Hotel Trondheim
# choibalsan - nearest hotel: Зүүн Ордон Зочид Буудал
# altay - nearest hotel: Sunshine Holiday Hotel
# mogocha - nearest hotel: 7Ka
# terrace - nearest hotel: Sandman Hotel Terrace
# petropavlovsk-kamchatsky - nearest hotel: ООО Постоялый двор
# merritt - nearest hotel: Coldwater Hotel
# nogliki - nearest hotel: Ноглики
# bodo - nearest hotel: Zefyr hotell
# whistler - nearest hotel: WorldMark Whistler - Cascade Lodge
# lensk - nearest hotel: No hotel found
# haapsalu - nearest hotel: Hotell Kongo
# promyshlennaya - nearest hotel: No hotel found
# hovd - nearest hotel: Khovd hotel
# ketchikan - nearest hotel: Cape Fox Lodge
# hailar - nearest hotel: 呼伦贝尔融府商务酒店
#                          City      Lat       Lng  Humidity Country  \
# 4           port-aux-francais -49.3500   70.2167        90      TF
# 5                    qaqortoq  60.7167  -46.0333        48      GL
# 9                   grytviken -54.2811  -36.5092        93      GS
# 12                 isafjordur  66.0755  -23.1240        87      IS
# 46                  kolyshley  52.7005   44.5367        74      RU
# 64                     anadyr  64.7500  177.4833        80      RU
# 89                   ulaangom  49.9811   92.0667        55      MN
# 100               olonkinbyen  70.9221   -8.7187        93      SJ
# 108                   selfoss  63.9331  -20.9971        79      IS
# 128               vilyuchinsk  52.9306  158.4028        80      RU
# 140                 berezovyy  51.6667  135.7000        81      RU
# 164             kamen'-na-obi  53.7884   81.3423        96      RU
# 173                      nuuk  64.1835  -51.7216        80      GL
# 211                      nehe  48.4833  124.8333        55      CN
# 223                     sitka  57.0531 -135.3300        44      US
# 255                gadzhiyevo  69.2551   33.3362        83      RU
# 258                    suntar  62.1444  117.6319        87      RU
# 263             labrador city  52.9463  -66.9114        75      CA
# 267                 trondheim  63.4305   10.3951        94      NO
# 271                choibalsan  48.0667  114.5000        48      MN
# 282                     altay  47.8667   88.1167        46      CN
# 288                   mogocha  53.7333  119.7667        73      RU
# 322                   terrace  54.5163 -128.6035        47      CA
# 338  petropavlovsk-kamchatsky  53.0452  158.6483        81      RU
# 367                   merritt  50.1123 -120.7942        83      CA
# 436                   nogliki  51.8333  143.1667        85      RU
# 439                      bodo  67.2800   14.4050        84      NO
# 445                  whistler  50.1164 -122.9695        75      CA
# 475                     lensk  60.7253  114.9278        75      RU
# 522                  haapsalu  58.9431   23.5414        85      EE
# 527            promyshlennaya  54.9159   85.6385        87      RU
# 531                      hovd  48.0056   91.6419        29      MN
# 562                 ketchikan  55.3422 -131.6461        38      US
# 590                    hailar  49.2000  119.7000        52      CN
#
#                              Hotel Name
# 4                               Keravel
# 5                        Hotel Qaqortoq
# 9                        No hotel found
# 12                           Hótel Horn
# 46                       No hotel found
# 64                         Гостевой дом
# 89                               АНДУУД
# 100                      No hotel found
# 108                           Miðgarður
# 128                              Победа
# 140                      No hotel found
# 164                     Гостиница "Обь"
# 173                              Nordbo
# 211                      No hotel found
# 223                  Aspen Suites Hotel
# 255                               Оазис
# 258                      No hotel found
# 263                           Carol Inn
# 267                Thon Hotel Trondheim
# 271             Зүүн Ордон Зочид Буудал
# 282              Sunshine Holiday Hotel
# 288                                 7Ka
# 322               Sandman Hotel Terrace
# 338                  ООО Постоялый двор
# 367                     Coldwater Hotel
# 436                             Ноглики
# 439                        Zefyr hotell
# 445  WorldMark Whistler - Cascade Lodge
# 475                      No hotel found
# 522                        Hotell Kongo
# 527                      No hotel found
# 531                         Khovd hotel
# 562                      Cape Fox Lodge
# 590                          呼伦贝尔融府商务酒店

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
#%%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 750,
    frame_height = 500,
    size = "Humidity",
    color = 'City',
    hover_cols= ['Hotel Name', 'Country']
)

# Display the map 
map_plot_2
# Out:
# :Overlay
#    .WMTS.I   :WMTS   [Longitude,Latitude]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
